# %%
# !pip install mysql-connector-python

# %% [markdown]
# # Task 1: Connect to the database

# %%
import mysql.connector as connector

connection = connector.connect(user = "Super_Admin", password = "7IRlsNPCacpK", db="littlelemondb")
cursor = connection.cursor()

# %% [markdown]
# # Task 2: Show all tables in the database

# %%
show_tables_query = "SHOW tables"
cursor.execute(show_tables_query)
 
results = cursor.fetchall()
print(results)
# Out:
# [('bookings',), ('customers',), ('menuitems',), ('menus',), ('orderdeliverystatus',), ('orders',), ('ordersview',), ('staff',)]

# %% [markdown]
# # Task 3: JOIN query — customers who spent more than $60

# %%
join_query = """
SELECT Customers.FullName, Customers.ContactNumber, Customers.Email, Orders.TotalCost
FROM Orders
JOIN Customers ON Orders.CustomerID = Customers.CustomerID
WHERE Orders.TotalCost > 60
"""
 
cursor.execute(join_query)
join_results = cursor.fetchall()
 
for row in join_results:
    print(row)
# Out:
# ('Brian Smith', '07700900002', 'brian.smith@example.com', Decimal('66.00'))
# ('Chidinma Okafor', '07700900003', 'chidinma.okafor@example.com', Decimal('180.00'))
# ('Elena Rossi', '07700900005', 'elena.rossi@example.com', Decimal('216.00'))

# %% [markdown]
# # Clean up

# %%
cursor.close()
connection.close()
